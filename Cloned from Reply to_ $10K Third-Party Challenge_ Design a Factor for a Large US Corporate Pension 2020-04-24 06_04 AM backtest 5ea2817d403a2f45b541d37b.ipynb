# %% [markdown]
# Run the cell below to create your tear sheet.

# %%
bt = get_backtest('5ea2817d403a2f45b541d37b')
bt.create_full_tear_sheet()
# Out:
# 100% Time:  0:01:40|##########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2014-02-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-04-06</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>50</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-0.541%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-2.239%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>1.734%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.30</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.09</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.09</td>
#     </tr>
#     <tr>
# ...
